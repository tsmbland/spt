# %%
import sys
sys.path.append('..')
from spt import *

# %matplotlib notebook

# %% [markdown]
# ### Import movie

# %%
path_to_file = '/Users/blandt/Desktop/SingleMolecule/Diffusion/August2020/PAR2halo_new/200820_par2halo_spt_1in16/e1/e1.tif'
movie = TiffStack(path_to_file)

# %% [markdown]
# ### View movie

# %%
# %matplotlib notebook
view_stack(movie, jupyter=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(IntSlider(value=0, description='Frame', max=1499), Output()), _dom_classes=('widget-inte…

# %% [markdown]
# ### Set parameters for feature detection

# %%
plot_calibration(movie, jupyter=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(IntSlider(value=0, description='Frame', max=1499), IntSlider(value=250, description='thr…

# %% [markdown]
# ### Optional: specify ROI

# %%
roi = ROI_jupyter(movie[0])
roi.run()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
print(roi.roi)
# Out:
# [[262.95454545  32.48701299]
#  [263.95257439  32.56048543]
#  [264.9500009   32.6417275 ]
#  ...
#  [259.95744203  32.31337986]
#  [260.95691583  32.36350127]
#  [261.95597074  32.42137373]]

# %% [markdown]
# ### Set up SPT class

# %%
spt = SPT(direc=path_to_file, roi=roi.roi, threshold=300, feat_size=5, separation=2, dist=5, memory=0, mtl=10, 
          parallel=True, save_path='.', start_frame=0)

# %% [markdown]
# ### Run

# %%
spt.run()
# Out:
# Frame 1499: 2 trajectories present.

# %% [markdown]
# ### Trajectories dataframe

# %%
traj = pd.read_csv('trajectories.csv')
traj
# Out:
#        frame           y           x        mass      size       ecc  \
# 0          0  213.964527  377.638636  491.958953  1.114387  0.353191
# 1          0  205.020551  358.888201  421.357514  1.180970  0.161423
# 2          0  196.968465  341.552958  430.342066  1.207674  0.312038
# 3          0  198.179102  330.161856  584.115346  1.201011  0.315280
# 4          0  198.990958  212.011253  676.661313  1.267855  0.178405
# 5          0  196.624546  312.918080  792.714530  1.214014  0.070538
# 6          0  195.909867  162.733099  542.439779  1.142692  0.181870
# 7          0  194.856861  240.065012  533.519419  1.124510  0.212050
# 8          0  218.214063  268.713518  398.228770  1.231719  0.313555
# 9          0  194.021296  259.679280  465.031862  1.256995  0.339305
# 10         0  192.174719  301.201773  597.918662  1.179435  0.133650
# 11         0  190.214783  374.523773  494.446915  1.245503  0.141434
# 12         0  185.784310  351.231090  520.167655  1.172127  0.159706
# ...

# %% [markdown]
# ### View tracking results

# %%
spt.plot_features(jupyter=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(IntSlider(value=0, description='Frame', max=1499), Output()), _dom_classes=('widget-inte…

# %% [markdown]
# ### View all trajectories

# %%
spt.plot_trajectories()
# Out:
# <img src="data:image/png;base64,..." width="640">
